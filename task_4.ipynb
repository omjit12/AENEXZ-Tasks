# %%
import pandas as pd

# %%
dataset=pd.read_csv("AMAZON_SALES.csv")
print(dataset)
# Out:
#      order_id  order_date   ship_date delivery_date order_status customer_id  \
# 0      A10000  2026-01-31  2026-01-31    2026-01-08    Delivered       C5691
# 1      A10001  2026-01-20  2026-02-03    2026-02-03    Delivered       C9811
# 2      A10002  2026-01-15  2026-02-07    2026-01-03    Delivered       C7341
# 3      A10003  2026-01-18  2026-01-15    2026-01-20    Delivered       C4012
# 4      A10004  2026-01-27  2026-01-04    2026-01-23    Delivered       C1328
# ...       ...         ...         ...           ...          ...         ...
# 9995   A19995  2026-02-08  2026-01-07    2026-01-10    Delivered       C3522
# 9996   A19996  2026-01-17  2026-01-23    2026-02-03    Delivered       C9510
# 9997   A19997  2026-01-17  2026-01-11    2026-01-15    Delivered       C3630
# 9998   A19998  2026-01-08  2026-01-18    2026-02-07    Delivered       C8299
# 9999   A19999  2026-01-31  2026-01-30    2026-02-08    Delivered       C7848
#
# ...

# %%
dataset.head(10)
# Out:
#   order_id  order_date   ship_date delivery_date order_status customer_id  \
# 0   A10000  2026-01-31  2026-01-31    2026-01-08    Delivered       C5691
# 1   A10001  2026-01-20  2026-02-03    2026-02-03    Delivered       C9811
# 2   A10002  2026-01-15  2026-02-07    2026-01-03    Delivered       C7341
# 3   A10003  2026-01-18  2026-01-15    2026-01-20    Delivered       C4012
# 4   A10004  2026-01-27  2026-01-04    2026-01-23    Delivered       C1328
# 5   A10005  2026-01-05  2026-01-12    2026-01-11    Delivered       C9019
# 6   A10006  2026-01-04  2026-01-10    2026-01-21    Delivered       C9866
# 7   A10007  2026-02-07  2026-02-01    2026-01-10    Delivered       C2638
# 8   A10008  2026-02-09  2026-02-03    2026-01-01    Delivered       C4823
# 9   A10009  2026-01-24  2026-01-26    2026-02-10    Delivered       C9948
#
#         customer_name country           state                 city  ...  \
# 0        Ricky Potter   India  South Carolina              New Joe  ...
# ...

# %%
dataset.tail()
# Out:
#      order_id  order_date   ship_date delivery_date order_status customer_id  \
# 9995   A19995  2026-02-08  2026-01-07    2026-01-10    Delivered       C3522
# 9996   A19996  2026-01-17  2026-01-23    2026-02-03    Delivered       C9510
# 9997   A19997  2026-01-17  2026-01-11    2026-01-15    Delivered       C3630
# 9998   A19998  2026-01-08  2026-01-18    2026-02-07    Delivered       C8299
# 9999   A19999  2026-01-31  2026-01-30    2026-02-08    Delivered       C7848
#
#         customer_name country     state               city  ... product_name  \
# 9995     Kelly Bryant   India   Alabama  West Kimberlyview  ...     question
# 9996  Kristina Barnes   India  Colorado       Jamesborough  ...         item
# 9997  Samuel Anderson   India   Montana       Lake Richard  ...        leave
# 9998       April King   India   Georgia         Millerview  ...          too
# 9999  Jennifer Rogers   India   Alabama         Taylorstad  ...        total
#
# ...

# %%
dataset.loc[0,"order_date"]
# Out:
# '2026-01-31'

# %%
dataset.iloc[:,[0,2]]
# Out:
#      order_id   ship_date
# 0      A10000  2026-01-31
# 1      A10001  2026-02-03
# 2      A10002  2026-02-07
# 3      A10003  2026-01-15
# 4      A10004  2026-01-04
# ...       ...         ...
# 9995   A19995  2026-01-07
# 9996   A19996  2026-01-23
# 9997   A19997  2026-01-11
# 9998   A19998  2026-01-18
# 9999   A19999  2026-01-30
#
# [10000 rows x 2 columns]

# %%
dataset.isna()
# Out:
#       order_id  order_date  ship_date  delivery_date  order_status  \
# 0        False       False      False          False         False
# 1        False       False      False          False         False
# 2        False       False      False          False         False
# 3        False       False      False          False         False
# 4        False       False      False          False         False
# ...        ...         ...        ...            ...           ...
# 9995     False       False      False          False         False
# 9996     False       False      False          False         False
# 9997     False       False      False          False         False
# 9998     False       False      False          False         False
# 9999     False       False      False          False         False
#
#       customer_id  customer_name  country  state   city  ...  product_name  \
# 0           False          False    False  False  False  ...         False
# ...

# %%
dataset.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# delivery_date     0
# order_status      0
# customer_id       0
# customer_name     0
# country           0
# state             0
# city              0
# product_id        0
# product_name      0
# category          0
# sub_category      0
# brand             0
# quantity          0
# unit_price        0
# discount          0
# shipping_cost     0
# total_sales       0
# payment_method    0
# dtype: int64

# %%
dataset.dropna()
# Out:
#      order_id  order_date   ship_date delivery_date order_status customer_id  \
# 0      A10000  2026-01-31  2026-01-31    2026-01-08    Delivered       C5691
# 1      A10001  2026-01-20  2026-02-03    2026-02-03    Delivered       C9811
# 2      A10002  2026-01-15  2026-02-07    2026-01-03    Delivered       C7341
# 3      A10003  2026-01-18  2026-01-15    2026-01-20    Delivered       C4012
# 4      A10004  2026-01-27  2026-01-04    2026-01-23    Delivered       C1328
# ...       ...         ...         ...           ...          ...         ...
# 9995   A19995  2026-02-08  2026-01-07    2026-01-10    Delivered       C3522
# 9996   A19996  2026-01-17  2026-01-23    2026-02-03    Delivered       C9510
# 9997   A19997  2026-01-17  2026-01-11    2026-01-15    Delivered       C3630
# 9998   A19998  2026-01-08  2026-01-18    2026-02-07    Delivered       C8299
# 9999   A19999  2026-01-31  2026-01-30    2026-02-08    Delivered       C7848
#
# ...

# %%
dataset.dropna(inplace=True)
dataset.fillna(200)
# Out:
#      order_id  order_date   ship_date delivery_date order_status customer_id  \
# 0      A10000  2026-01-31  2026-01-31    2026-01-08    Delivered       C5691
# 1      A10001  2026-01-20  2026-02-03    2026-02-03    Delivered       C9811
# 2      A10002  2026-01-15  2026-02-07    2026-01-03    Delivered       C7341
# 3      A10003  2026-01-18  2026-01-15    2026-01-20    Delivered       C4012
# 4      A10004  2026-01-27  2026-01-04    2026-01-23    Delivered       C1328
# ...       ...         ...         ...           ...          ...         ...
# 9995   A19995  2026-02-08  2026-01-07    2026-01-10    Delivered       C3522
# 9996   A19996  2026-01-17  2026-01-23    2026-02-03    Delivered       C9510
# 9997   A19997  2026-01-17  2026-01-11    2026-01-15    Delivered       C3630
# 9998   A19998  2026-01-08  2026-01-18    2026-02-07    Delivered       C8299
# 9999   A19999  2026-01-31  2026-01-30    2026-02-08    Delivered       C7848
#
# ...

# %%
dataset['order_date']=pd.to_datetime(dataset['order_date'],errors='coerce')
dataset['order_date']=dataset['order_date'].dt.strftime('%d/%m/%y')
print(dataset)
# Out:
#      order_id order_date   ship_date delivery_date order_status customer_id  \
# 0      A10000   31/01/26  2026-01-31    2026-01-08    Delivered       C5691
# 1      A10001   20/01/26  2026-02-03    2026-02-03    Delivered       C9811
# 2      A10002   15/01/26  2026-02-07    2026-01-03    Delivered       C7341
# 3      A10003   18/01/26  2026-01-15    2026-01-20    Delivered       C4012
# 4      A10004   27/01/26  2026-01-04    2026-01-23    Delivered       C1328
# ...       ...        ...         ...           ...          ...         ...
# 9995   A19995   08/02/26  2026-01-07    2026-01-10    Delivered       C3522
# 9996   A19996   17/01/26  2026-01-23    2026-02-03    Delivered       C9510
# 9997   A19997   17/01/26  2026-01-11    2026-01-15    Delivered       C3630
# 9998   A19998   08/01/26  2026-01-18    2026-02-07    Delivered       C8299
# 9999   A19999   31/01/26  2026-01-30    2026-02-08    Delivered       C7848
#
# ...

# %%
# for duplicates

print(dataset.duplicated())
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Length: 10000, dtype: bool

# %%
dataset.drop_duplicates(inplace=True)
print(dataset.drop_duplicates())
# Out:
#      order_id order_date   ship_date delivery_date order_status customer_id  \
# 0      A10000   31/01/26  2026-01-31    2026-01-08    Delivered       C5691
# 1      A10001   20/01/26  2026-02-03    2026-02-03    Delivered       C9811
# 2      A10002   15/01/26  2026-02-07    2026-01-03    Delivered       C7341
# 3      A10003   18/01/26  2026-01-15    2026-01-20    Delivered       C4012
# 4      A10004   27/01/26  2026-01-04    2026-01-23    Delivered       C1328
# ...       ...        ...         ...           ...          ...         ...
# 9995   A19995   08/02/26  2026-01-07    2026-01-10    Delivered       C3522
# 9996   A19996   17/01/26  2026-01-23    2026-02-03    Delivered       C9510
# 9997   A19997   17/01/26  2026-01-11    2026-01-15    Delivered       C3630
# 9998   A19998   08/01/26  2026-01-18    2026-02-07    Delivered       C8299
# 9999   A19999   31/01/26  2026-01-30    2026-02-08    Delivered       C7848
#
# ...
